# %% [markdown]
# <a href="https://colab.research.google.com/github/tarundb2005-create/Machine-Learning/blob/main/DecisionTree/DecisionTree%20-%20Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')
df.head(5)

# %%
inputs = df.drop(
    ['Survived', 'Name', 'Parch', 'Ticket', 'Cabin', 'Embarked'],
    axis=1
)

inputs.head()

# %%
target = df['Survived']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Pclass = LabelEncoder()
le_Sex = LabelEncoder()
le_Age = LabelEncoder()
le_SibSp = LabelEncoder()

# %%
inputs['Sex'] = le_Sex.fit_transform(inputs['Sex'])

# %%
inputs

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %%
model.fit(inputs,target)
